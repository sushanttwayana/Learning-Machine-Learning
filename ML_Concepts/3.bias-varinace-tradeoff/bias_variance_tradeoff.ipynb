# %%
import random
import numpy as np

outcome = []
for i in range(1000000):
  outcome.append(random.randint(1,6))

np.array(outcome).mean()
# Out:
# np.float64(3.497288)

# %%
from mlxtend.evaluate import bias_variance_decomp
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from mlxtend.data import boston_housing_data
from sklearn.model_selection import train_test_split


X, y = boston_housing_data()
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=123,
                                                    shuffle=True)

# %%
lr = LinearRegression()

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        lr, X_train, y_train, X_test, y_test,
        loss='mse',
        random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
# Out:
# Average expected loss: 29.891
# Average bias: 28.609
# Average variance: 1.282

# %%
dt = DecisionTreeRegressor(random_state=123)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        dt, X_train, y_train, X_test, y_test,
        loss='mse',
        random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
# Out:
# Average expected loss: 31.536
# Average bias: 14.096
# Average variance: 17.440

# %%
# !pip install mlxtend --upgrade
# Out:
# Requirement already satisfied: mlxtend in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (0.23.4)
# Collecting mlxtend
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# INFO: pip is looking at multiple versions of mlxtend to determine which version is compatible with other requirements. This could take a while.
# Requirement already satisfied: scipy>=1.2.1 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (2.2.6)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vanilla\anaconda3\envs\myenv\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
